# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df1=pd.read_csv('C:/Users/ADITYA/Documents/GitHub/Technocolab Final Project/datasets/IRAhandle_tweets_1.csv')

# %%
df1.shape
# Out:
# (381016, 15)

# %%
#no. of raws of all the files
#381016+397232+368885+388452+331821+324512+365603+378295+37555

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381016 entries, 0 to 381015
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   external_author_id  381016 non-null  float64
#  1   author              381016 non-null  object
#  2   content             381016 non-null  object
#  3   region              380698 non-null  object
#  4   language            381016 non-null  object
#  5   publish_date        381016 non-null  object
#  6   harvested_date      381016 non-null  object
#  7   following           381016 non-null  int64
#  8   followers           381016 non-null  int64
#  9   updates             381016 non-null  int64
#  10  post_type           197250 non-null  object
#  11  account_type        381016 non-null  object
#  12  new_june_2018       381016 non-null  int64
#  13  retweet             381016 non-null  int64
#  14  account_category    381016 non-null  object
# ...

# %%
# Croot = "C:/Users/ADITYA/Documents/GitHub/Technocolab Final Project/datasets/"
# for path, subdirs, files in os.walk(root):
#     for name in files:
#         print(os.path.join(path, name))

# %%
from os import chdir
from glob import glob
import pandas as pdlib

# Move to the path that holds our CSV files
csv_file_path = 'C:/Users/ADITYA/Documents/GitHub/Technocolab Final Project/datasets/'
chdir(csv_file_path)

# %%
# List all CSV files in the working dir
file_pattern = "csv"
list_of_files = [file for file in glob('*.{}'.format(file_pattern))]
print(list_of_files)
# Out:
# ['IRAhandle_tweets_1.csv', 'IRAhandle_tweets_2.csv', 'IRAhandle_tweets_3.csv', 'IRAhandle_tweets_4.csv', 'IRAhandle_tweets_5.csv', 'IRAhandle_tweets_6.csv', 'IRAhandle_tweets_7.csv', 'IRAhandle_tweets_8.csv', 'IRAhandle_tweets_9.csv']

# %%
# def produceOneCSV(list_of_files, file_out):
#     # Consolidate all CSV files into one object
#     result_obj = pdlib.concat([pdlib.read_csv(file) for file in list_of_files])
#     # Convert the above object into a csv file and export
#     # result_obj.to_csv(file_out, index=False, encoding="utf-8")
#     return result_obj
# file_out = "ConsolidateOutput.csv"
# produceOneCSV(list_of_files, file_out)

# %%
# Consolidate all CSV files into one object
result_obj = pdlib.concat([pdlib.read_csv(file) for file in list_of_files])
df=pd.DataFrame(result_obj)

# %%
df
# Out:
#        external_author_id           author  \
# 0            9.060000e+17           10_GOP
# 1            9.060000e+17           10_GOP
# 2            9.060000e+17           10_GOP
# 3            9.060000e+17           10_GOP
# 4            9.060000e+17           10_GOP
# ...                   ...              ...
# 37550        3.093874e+09  _YOUR_LIFESTYLE
# 37551        3.093874e+09  _YOUR_LIFESTYLE
# 37552        3.093874e+09  _YOUR_LIFESTYLE
# 37553        3.093874e+09  _YOUR_LIFESTYLE
# 37554        3.093874e+09  _YOUR_LIFESTYLE
#
#                                                  content   region language  \
# 0      "We have a sitting Democrat US Senator on tria...  Unknown  English
# 1      Marshawn Lynch arrives to game in anti-Trump s...  Unknown  English
# 2      Daughter of fallen Navy Sailor delivers powerf...  Unknown  English
# 3      JUST IN: President Trump dedicates Presidents ...  Unknown  English
# ...

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# post_type             1662425
# region                   8843
# account_type              363
# external_author_id          4
# content                     1
# account_category            0
# retweet                     0
# new_june_2018               0
# updates                     0
# followers                   0
# following                   0
# harvested_date              0
# publish_date                0
# language                    0
# author                      0
# dtype: int64

# %%
df.account_category.value_counts()
# Out:
# NonEnglish      837725
# RightTroll      719087
# NewsFeed        599294
# LeftTroll       427811
# HashtagGamer    241827
# Commercial      122582
# Unknown          13905
# Fearmonger       11140
# Name: account_category, dtype: int64

# %%
only_eng_df = df[df['language']=='English']

# %%
only_eng_df
# Out:
#        external_author_id           author  \
# 0            9.060000e+17           10_GOP
# 1            9.060000e+17           10_GOP
# 2            9.060000e+17           10_GOP
# 3            9.060000e+17           10_GOP
# 4            9.060000e+17           10_GOP
# ...                   ...              ...
# 36991        3.093874e+09  _YOUR_LIFESTYLE
# 37053        3.093874e+09  _YOUR_LIFESTYLE
# 37337        3.093874e+09  _YOUR_LIFESTYLE
# 37410        3.093874e+09  _YOUR_LIFESTYLE
# 37431        3.093874e+09  _YOUR_LIFESTYLE
#
#                                                  content         region  \
# 0      "We have a sitting Democrat US Senator on tria...        Unknown
# 1      Marshawn Lynch arrives to game in anti-Trump s...        Unknown
# 2      Daughter of fallen Navy Sailor delivers powerf...        Unknown
# 3      JUST IN: President Trump dedicates Presidents ...        Unknown
# 4      19,000 RESPECTING our National Anthem! #StandF...        Unknown
# ...
